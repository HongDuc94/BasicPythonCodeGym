# %% [markdown]
# # Bài 1
# ![image.png](attachment:image.png)

# %%
diem_toan = 8
diem_ly = 8
diem_hoa = 7
trung_binh = (diem_toan + diem_ly + diem_hoa)/3
print(trung_binh)
if trung_binh >= 8:
    print('Học sinh giỏi')
elif trung_binh <8 and trung_binh >=6:
    print('Học sinh khá')
elif trung_binh <6:
    print('Học sinh trung bình')
# Out:
# 7.666666666666667
# Học sinh khá

# %% [markdown]
# # Bài 2
# ![image.png](attachment:image.png)

# %%
participation_percent = 0.8
course_complete_percent = 0.8
final_exam_mark = 6
print(participation_percent >= 0.75 and course_complete_percent >= 0.8 and final_exam_mark >= 7.5)
# Out:
# False

# %% [markdown]
# # Bài 3
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
velocity_km = 33
distance_per_min_m = velocity / 60 * 1000
time = 72
distance_travelled_km= distance_per_min_m * time /1000
print(distance_per_min_m)
print(distance_travelled_km)
# Out:
# 550.0
# 39.6

# %% [markdown]
# # Bài 4
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
rectangle_length = 16
rectangle_width = 10
rectangle_area_1 = rectangle_length * rectangle_width
rectangle_length += 4
rectangle_area_2 = rectangle_length * rectangle_width
area_delta = rectangle_area_2 - rectangle_area_1
area_delta_percentage = area_delta / rectangle_area_1 * 100
print(rectangle_area_1)
print(rectangle_area_2)
print(area_delta_percentage)
# Out:
# 160
# 200
# 25.0

# %% [markdown]
# # Bài 5
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bike_velocity_km = 12
motorbike_velocity_km = 36
distance_difference_km = 48
time_to_catch_up_h = distance_difference_km/(motorbike_velocity_km - bike_velocity_km)
print(time_to_catch_up_h)
# Out:
# 2.0
